# %% [markdown]
# V. Resampling and Simulation (10 points)
#
# What you should do:
#
#  Implement a bootstrap (for mean, proportion, or model)
#
#  (Optional) Run a Monte Carlo simulation to study behavior
#
#  Explain what the variability in your results means
#
#
#
# #### See Section V in final_pipeline.ipynb
